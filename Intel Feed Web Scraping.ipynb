# %%
import pandas as pd
import numpy as np
import bs4
from bs4 import BeautifulSoup
import time
import sys
import requests

# %%
# Web request of target source(s). Starting with CISA's advisory page
cisa_advisory = requests.get("https://www.cisa.gov/news-events/cybersecurity-advisories")

# %%
# Status confirmation
print(cisa_advisory.status_code)
# Out:
# 200

# %%
cisa_html = cisa_advisory.content

# %%
print(cisa_html)
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#" class="no-js">\n  <head>\n    <meta charset="utf-8" />\n<script async src="https://www.googletagmanager.com/gtag/js?id=G-9MDR73GM0K"></script>\n<script>window.dataLayer = window.dataLayer || [];function gtag(){dataLayer.push(arguments)};gtag("js", new Date());gtag("set", "developer_id.dMDhkMT", true);gtag("config", "G-9MDR73GM0K", {"groups":"default","page_placeholder":"PLACEHOLDER_page_location"});</script>\n<meta name="description" content="View Cybersecurity Advisories Only" />\n<link rel="canonical" href="https://www.cisa.gov/news-events/cybersecurity-advisories" />\n<meta property="og:site_name" content="Cybersecurity and Infrastructure Security Agency CISA" />\n<meta property="og:type" content="website" />\n<meta property="og:url" content="https://www.cisa.gov/news-events/cybersecurity-advisories" />\n<meta property="og:title" content="Cybersecurity Alerts &amp; Advisories | CISA" />\n<meta property="og:description" content="View Cybersecurity Advisories Only" />\n<meta name="Generator" content="Drupal 9 (https://www.drupal.org)" />\n<meta name="MobileOptimized" content="width" />\n<meta name="HandheldFriendly" content="true" />\n<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n<link rel="icon" href="/profiles/cisad8_gov/themes/custom/gesso/favicon.png" type="image/png" />\n\n    <title>Cybersecurity Alerts &amp; Advisories | CISA</title>\n    <link rel="stylesheet" media="all" href="/core/modules/system/css/components/ajax-progress.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/align.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/autocomplete-loading.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/fieldgroup.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/container-inline.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/clearfix.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/details.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/hidden.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/item-list.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/js.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/nowrap.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/position-container.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/progress.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/reset-appearance.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/resize.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/sticky-header.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/system-status-counter.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/system-status-report-counters.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/system-status-report-general-info.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/tabledrag.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/tablesort.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/core/modules/system/css/components/tree-child.module.css?rxozri" />\n<link rel="stylesheet" media="all" href="/modul ...

# %%
# Find latest Articles by scanning for and collecting all HTML tags

# %%
cisa_soup = BeautifulSoup(cisa_html)

# %%
cisa_advisories = cisa_soup.find_all("article")

# %%
len(cisa_advisories)
# Out:
# 10

# %%
import time

for adv in cisa_advisories:
    
    #print(adv)
    i = 0
    for content in adv:
        print("Iteration Entry Number: {}".format(i))
        print(content)
        time.sleep(2)
        i = i + 1
        # This helped pinpoint what part was actual content vs whitespace. Note: content[1] has all the meat
        # Also lows us to identify the specific pieces of data and where they are located in our advisory objects
        # Namely: <time> for our publication date, <span> for the adviory title, <a href> for the article link,
# Out:
# Iteration Entry Number: 0
#
#
# Iteration Entry Number: 1
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2023-07-12T12:00:00Z">Jul 12, 2023</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2023/07/12/cisa-releases-one-industrial-control-systems-advisory" target="_self">
# <span>CISA Releases One Industrial Control Systems Advisory</span>
# </a> </h3>
# </div>
# </div>
# Iteration Entry Number: 2
#
#
# Iteration Entry Number: 0
#
#
# Iteration Entry Number: 1
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2023-07-12T12:00:00Z">Jul 12, 2023</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2023/07/12/cisa-and-fbi-release-cybersecurity-advisory-enhanced-monitoring-detect-apt-activity-targeting" target="_self">
# <span>CISA and FBI Release Cybersecurity Advisory on Enhanced Monitoring to Detect APT Activity Targeting Outlook Online</span>
# </a> </h3>
# </div>
# </div>
# Iteration Entry Number: 2
#
#
# Iteration Entry Number: 0
#
#
# Iteration Entry Number: 1
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2023-07-12T12:00:00Z">Jul 12, 2023</time>
# </div>
# <div class="c-teaser__meta">ICS Advisory | ICSA-23-193-01</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/ics-advisories/icsa-23-193-01" target="_self">
# <span>Rockwell Automation Select Communication Modules</span>
# </a> </h3>
# </div>
# </div>
# Iteration Entry Number: 2
#
#
# Iteration Entry Number: 0
#
#
# Iteration Entry Number: 1
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2023-07-12T12:00:00Z">Jul 12, 2023</time>
# </div>
# <div class="c-teaser__meta">Cybersecurity Advisory | AA23-193A</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/cybersecurity-advisories/aa23-193a" target="_self">
# <span>Enhanced Monitoring to Detect APT Activity Targeting Outlook Online</span>
# </a> </h3>
# </div>
# </div>
# Iteration Entry Number: 2
#
#
# Iteration Entry Number: 0
#
#
# Iteration Entry Number: 1
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2023-07-11T12:00:00Z">Jul 11, 2023</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2023/07/11/microsoft-releases-july-2023-security-updates" target="_self">
# <span>Microsoft Releases July 2023 Security Updates</span>
# </a> </h3>
# </div>
# </div>
# Iteration Entry Number: 2
#
#
# Iteration Entry Number: 0
#
#
# Iteration Entry Number: 1
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2023-07-11T12:00:00Z">Jul 11, 2023</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2023/07/11/fortinet-releases-security-update-fortios-and-fortiproxy" target="_self">
# <span>Fortinet Releases Security Update for FortiOS and FortiProxy</span>
# </a> </h3>
# </div>
# </div>
# Iteration Entry Number: 2
#
#
# Iteration Entry Number: 0
#
#
# Iteration Entry Number: 1
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2023-07-11T12:00:00Z">Jul 11, 2023</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2023/07/11/adobe-releases-security-updates-coldfusion-and-indesign" target="_self">
# <span>Adobe Releases Security Updates for ColdFusion and InDesign</span>
# </a> </h3>
# </div>
# </div>
# Iteration Entry Number: 2
#
#
# Iteration Entry Number: 0
#
#
# Iteration Entry Number: 1
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2023-07-11T12:00:00Z">Jul 11, 2023</time>
# </div>
# <div class="c-teaser__meta">Alert</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/alerts/2023/07/11/mozilla-releases-security-update-firefox-and-firefox-esr" target="_self">
# <span>Mozilla Releases Security Update for Firefox and Firefox ESR</span>
# </a> </h3>
# </div>
# </div>
# Iteration Entry Number: 2
#
#
# Iteration Entry Number: 0
#
#
# Iteration Entry Number: 1
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2023-07-11T12:00:00Z">Jul 11, 2023</time>
# </div>
# <div class="c-teaser__meta">ICS Advisory | ICSA-23-192-03</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/ics-advisories/icsa-23-192-03" target="_self">
# <span>Panasonic Control FPWin Pro7</span>
# </a> </h3>
# </div>
# </div>
# Iteration Entry Number: 2
#
#
# Iteration Entry Number: 0
#
#
# Iteration Entry Number: 1
# <div class="c-teaser__row">
# <div class="c-teaser__content">
# <div class="c-teaser__eyebrow">
# <div class="c-teaser__date"><time datetime="2023-07-11T12:00:00Z">Jul 11, 2023</time>
# </div>
# <div class="c-teaser__meta">ICS Advisory | ICSA-23-192-02</div>
# </div>
# <h3 class="c-teaser__title">
# <a href="/news-events/ics-advisories/icsa-23-192-02" target="_self">
# <span>​Sensormatic Electronics iSTAR</span>
# </a> </h3>
# </div>
# </div>
# Iteration Entry Number: 2

# %%
'''
Here we had two bs4.element.NavigableString objects as whitespace padding in each content object. 
We can ignore them and focus on bs4.element.Tag objects where the content we are looking for is actually held.

Focuses on the bs4.element.Tag and extracts the data we need.
'''
import time

for adv in cisa_advisories:
    for content in adv:
        print(type(content))
        # Extracting URLs, Titles, and publication date
        if type(content) == bs4.element.Tag:
            print(content.find("time").text)
            print(content.find("span").text)
            print(content.find("a")['href'])
            print(content.find("div").text)
            time.sleep(2)
        else:
            pass
# Out:
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# Jul 12, 2023
# CISA Releases One Industrial Control Systems Advisory
# /news-events/alerts/2023/07/12/cisa-releases-one-industrial-control-systems-advisory
#
#
# Jul 12, 2023
#
# Alert
#
#
#
# CISA Releases One Industrial Control Systems Advisory
#
#
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# Jul 12, 2023
# CISA and FBI Release Cybersecurity Advisory on Enhanced Monitoring to Detect APT Activity Targeting Outlook Online
# /news-events/alerts/2023/07/12/cisa-and-fbi-release-cybersecurity-advisory-enhanced-monitoring-detect-apt-activity-targeting
#
#
# Jul 12, 2023
#
# Alert
#
#
#
# CISA and FBI Release Cybersecurity Advisory on Enhanced Monitoring to Detect APT Activity Targeting Outlook Online
#
#
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# Jul 12, 2023
# Rockwell Automation Select Communication Modules
# /news-events/ics-advisories/icsa-23-193-01
#
#
# Jul 12, 2023
#
# ICS Advisory | ICSA-23-193-01
#
#
#
# Rockwell Automation Select Communication Modules
#
#
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# Jul 12, 2023
# Enhanced Monitoring to Detect APT Activity Targeting Outlook Online
# /news-events/cybersecurity-advisories/aa23-193a
#
#
# Jul 12, 2023
#
# Cybersecurity Advisory | AA23-193A
#
#
#
# Enhanced Monitoring to Detect APT Activity Targeting Outlook Online
#
#
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# Jul 11, 2023
# Microsoft Releases July 2023 Security Updates
# /news-events/alerts/2023/07/11/microsoft-releases-july-2023-security-updates
#
#
# Jul 11, 2023
#
# Alert
#
#
#
# Microsoft Releases July 2023 Security Updates
#
#
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# Jul 11, 2023
# Fortinet Releases Security Update for FortiOS and FortiProxy
# /news-events/alerts/2023/07/11/fortinet-releases-security-update-fortios-and-fortiproxy
#
#
# Jul 11, 2023
#
# Alert
#
#
#
# Fortinet Releases Security Update for FortiOS and FortiProxy
#
#
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# Jul 11, 2023
# Adobe Releases Security Updates for ColdFusion and InDesign
# /news-events/alerts/2023/07/11/adobe-releases-security-updates-coldfusion-and-indesign
#
#
# Jul 11, 2023
#
# Alert
#
#
#
# Adobe Releases Security Updates for ColdFusion and InDesign
#
#
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# Jul 11, 2023
# Mozilla Releases Security Update for Firefox and Firefox ESR
# /news-events/alerts/2023/07/11/mozilla-releases-security-update-firefox-and-firefox-esr
#
#
# Jul 11, 2023
#
# Alert
#
#
#
# Mozilla Releases Security Update for Firefox and Firefox ESR
#
#
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# Jul 11, 2023
# Panasonic Control FPWin Pro7
# /news-events/ics-advisories/icsa-23-192-03
#
#
# Jul 11, 2023
#
# ICS Advisory | ICSA-23-192-03
#
#
#
# Panasonic Control FPWin Pro7
#
#
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.NavigableString'>
# <class 'bs4.element.Tag'>
# Jul 11, 2023
# ​Sensormatic Electronics iSTAR
# /news-events/ics-advisories/icsa-23-192-02
#
#
# Jul 11, 2023
#
# ICS Advisory | ICSA-23-192-02
#
#
#
# ​Sensormatic Electronics iSTAR
#
#
# <class 'bs4.element.NavigableString'>

# %%
# Finally we can modify this approach to ingest our data directly into a dataframe

import time

df = pd.DataFrame(columns=("Publication Date", "Title", "URL", "Classification")) # Maybe add description if theres time

for adv in cisa_advisories:
    entry =[]
    for content in adv:
        # Extracting URLs, Titles, and publication date
        if type(content) == bs4.element.Tag:
            entry.append(content.find("time").text)
            entry.append(content.find("span").text)
            entry.append(content.find("a")['href'])
            print(content.find("div").text.split("\n")[4])
            entry.append(content.find("div").text.split("\n")[4])
            #print(entry)
            df.loc[len(df)] = entry
            time.sleep(2)
        else:
            pass
# Out:
# Alert
# Alert
# ICS Advisory | ICSA-23-193-01
# Cybersecurity Advisory | AA23-193A
# Alert
# Alert
# Alert
# Alert
# ICS Advisory | ICSA-23-192-03
# ICS Advisory | ICSA-23-192-02

# %%
# checking our DataFrame
df
# Out:
#   Publication Date                                              Title  \
# 0     Jul 12, 2023  CISA Releases One Industrial Control Systems A...
# 1     Jul 12, 2023  CISA and FBI Release Cybersecurity Advisory on...
# 2     Jul 12, 2023   Rockwell Automation Select Communication Modules
# 3     Jul 12, 2023  Enhanced Monitoring to Detect APT Activity Tar...
# 4     Jul 11, 2023      Microsoft Releases July 2023 Security Updates
# 5     Jul 11, 2023  Fortinet Releases Security Update for FortiOS ...
# 6     Jul 11, 2023  Adobe Releases Security Updates for ColdFusion...
# 7     Jul 11, 2023  Mozilla Releases Security Update for Firefox a...
# 8     Jul 11, 2023                       Panasonic Control FPWin Pro7
# 9     Jul 11, 2023                     ​Sensormatic Electronics iSTAR
#
#                                                  URL  \
# 0  /news-events/alerts/2023/07/12/cisa-releases-o...
# 1  /news-events/alerts/2023/07/12/cisa-and-fbi-re...
# 2         /news-events/ics-advisories/icsa-23-193-01
# 3    /news-events/cybersecurity-advisories/aa23-193a
# 4  /news-events/alerts/2023/07/11/microsoft-relea...
# 5  /news-events/alerts/2023/07/11/fortinet-releas...
# 6  /news-events/alerts/2023/07/11/adobe-releases-...
# 7  /news-events/alerts/2023/07/11/mozilla-release...
# 8         /news-events/ics-advisories/icsa-23-192-03
# 9         /news-events/ics-advisories/icsa-23-192-02
#
#                        Classification
# 0                               Alert
# 1                               Alert
# 2       ICS Advisory | ICSA-23-193-01
# 3  Cybersecurity Advisory | AA23-193A
# 4                               Alert
# 5                               Alert
# 6                               Alert
# 7                               Alert
# 8       ICS Advisory | ICSA-23-192-03
# 9       ICS Advisory | ICSA-23-192-02

# %%
'''
Only shows 10 results because our main page only displays 10. 
Find a way to:
1. expand window width, 
2. overcome page limits, 
3. embed links and 
4. Create our rolling window
5. Stream Intel Feed
'''
# Out:
# '\nOnly shows 10 results because our main page only displays 10. \nFind a way to:\n1. expand window width, \n2. overcome page limits, \n3. embed links and \n4. Create our rolling window\n5. Stream Intel Feed\n'

# %% [markdown]
# ## Expanding Width of our datarame feed window ##

# %%
pd.set_option('display.max_colwidth', 1000)
df.head()
# Out:
#   Publication Date  \
# 0     Jul 12, 2023
# 1     Jul 12, 2023
# 2     Jul 12, 2023
# 3     Jul 12, 2023
# 4     Jul 11, 2023
#
#                                                                                                                 Title  \
# 0                                                               CISA Releases One Industrial Control Systems Advisory
# 1  CISA and FBI Release Cybersecurity Advisory on Enhanced Monitoring to Detect APT Activity Targeting Outlook Online
# 2                                                                    Rockwell Automation Select Communication Modules
# 3                                                 Enhanced Monitoring to Detect APT Activity Targeting Outlook Online
# 4                                                                       Microsoft Releases July 2023 Security Updates
#
#                                                                                                                             URL  \
# 0                                          /news-events/alerts/2023/07/12/cisa-releases-one-industrial-control-systems-advisory
# 1  /news-events/alerts/2023/07/12/cisa-and-fbi-release-cybersecurity-advisory-enhanced-monitoring-detect-apt-activity-targeting
# 2                                                                                    /news-events/ics-advisories/icsa-23-193-01
# 3                                                                               /news-events/cybersecurity-advisories/aa23-193a
# 4                                                  /news-events/alerts/2023/07/11/microsoft-releases-july-2023-security-updates
#
#                        Classification
# 0                               Alert
# 1                               Alert
# 2       ICS Advisory | ICSA-23-193-01
# 3  Cybersecurity Advisory | AA23-193A
# 4                               Alert

# %% [markdown]
# ## Consolidating Pages to build a comprehensive list of advisories ##

# %%
# This can be done by creating new webrequest objects and again distilling down to our target content
# We can start by extracting the total number of pages from the "Last" page link.

for link in cisa_soup.find_all("a"):
    try:
        if link["class"]==['c-pager__link', 'c-pager__link--last']: #info obtained through combination of inspect and print
            last_page = int(link["href"].strip("?page="))
            print(last_page)
    except:
        continue
# Out:
# 662

# %%
# Storing a list of all the advisory pages

i = 0
cisa_advisory_pages = []
while i < last_page:
    cisa_advisory_pages.append('https://www.cisa.gov/news-events/cybersecurity-advisories?page={}'.format(i))
    i = i + 1
cisa_advisory_pages
# Out:
# ['https://www.cisa.gov/news-events/cybersecurity-advisories?page=0',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=1',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=2',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=3',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=4',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=5',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=6',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=7',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=8',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=9',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=10',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=11',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=12',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=13',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=14',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=15',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=16',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=17',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=18',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=19',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=20',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=21',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=22',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=23',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=24',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=25',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=26',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=27',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=28',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=29',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=30',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=31',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=32',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=33',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=34',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=35',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=36',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=37',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=38',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=39',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=40',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=41',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=42',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=43',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=44',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=45',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=46',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=47',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=48',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=49',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=50',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=51',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=52',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=53',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=54',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=55',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=56',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=57',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=58',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=59',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=60',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=61',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=62',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=63',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=64',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=65',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=66',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=67',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=68',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=69',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=70',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=71',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=72',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=73',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=74',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=75',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=76',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=77',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=78',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=79',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=80',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=81',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=82',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=83',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=84',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=85',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=86',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=87',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=88',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=89',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=90',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=91',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=92',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=93',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=94',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=95',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=96',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=97',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=98',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=99',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=100',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=101',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=102',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=103',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=104',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=105',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=106',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=107',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=108',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=109',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=110',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=111',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=112',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=113',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=114',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=115',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=116',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=117',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=118',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=119',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=120',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=121',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=122',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=123',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=124',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=125',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=126',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=127',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=128',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=129',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=130',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=131',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=132',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=133',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=134',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=135',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=136',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=137',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=138',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=139',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=140',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=141',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=142',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=143',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=144',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=145',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=146',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=147',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=148',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=149',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=150',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=151',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=152',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=153',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=154',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=155',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=156',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=157',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=158',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=159',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=160',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=161',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=162',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=163',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=164',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=165',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=166',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=167',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=168',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=169',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=170',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=171',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=172',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=173',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=174',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=175',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=176',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=177',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=178',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=179',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=180',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=181',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=182',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=183',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=184',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=185',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=186',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=187',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=188',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=189',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=190',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=191',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=192',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=193',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=194',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=195',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=196',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=197',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=198',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=199',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=200',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=201',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=202',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=203',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=204',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=205',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=206',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=207',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=208',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=209',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=210',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=211',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=212',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=213',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=214',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=215',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=216',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=217',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=218',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=219',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=220',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=221',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=222',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=223',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=224',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=225',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=226',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=227',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=228',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=229',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=230',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=231',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=232',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=233',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=234',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=235',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=236',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=237',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=238',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=239',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=240',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=241',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=242',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=243',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=244',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=245',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=246',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=247',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=248',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=249',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=250',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=251',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=252',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=253',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=254',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=255',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=256',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=257',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=258',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=259',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=260',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=261',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=262',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=263',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=264',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=265',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=266',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=267',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=268',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=269',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=270',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=271',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=272',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=273',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=274',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=275',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=276',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=277',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=278',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=279',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=280',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=281',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=282',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=283',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=284',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=285',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=286',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=287',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=288',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=289',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=290',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=291',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=292',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=293',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=294',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=295',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=296',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=297',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=298',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=299',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=300',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=301',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=302',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=303',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=304',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=305',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=306',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=307',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=308',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=309',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=310',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=311',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=312',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=313',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=314',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=315',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=316',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=317',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=318',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=319',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=320',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=321',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=322',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=323',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=324',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=325',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=326',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=327',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=328',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=329',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=330',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=331',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=332',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=333',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=334',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=335',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=336',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=337',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=338',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=339',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=340',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=341',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=342',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=343',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=344',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=345',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=346',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=347',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=348',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=349',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=350',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=351',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=352',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=353',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=354',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=355',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=356',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=357',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=358',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=359',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=360',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=361',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=362',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=363',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=364',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=365',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=366',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=367',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=368',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=369',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=370',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=371',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=372',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=373',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=374',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=375',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=376',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=377',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=378',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=379',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=380',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=381',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=382',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=383',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=384',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=385',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=386',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=387',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=388',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=389',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=390',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=391',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=392',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=393',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=394',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=395',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=396',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=397',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=398',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=399',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=400',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=401',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=402',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=403',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=404',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=405',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=406',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=407',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=408',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=409',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=410',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=411',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=412',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=413',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=414',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=415',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=416',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=417',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=418',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=419',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=420',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=421',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=422',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=423',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=424',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=425',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=426',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=427',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=428',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=429',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=430',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=431',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=432',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=433',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=434',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=435',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=436',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=437',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=438',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=439',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=440',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=441',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=442',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=443',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=444',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=445',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=446',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=447',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=448',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=449',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=450',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=451',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=452',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=453',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=454',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=455',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=456',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=457',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=458',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=459',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=460',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=461',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=462',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=463',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=464',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=465',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=466',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=467',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=468',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=469',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=470',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=471',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=472',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=473',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=474',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=475',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=476',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=477',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=478',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=479',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=480',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=481',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=482',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=483',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=484',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=485',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=486',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=487',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=488',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=489',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=490',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=491',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=492',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=493',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=494',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=495',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=496',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=497',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=498',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=499',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=500',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=501',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=502',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=503',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=504',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=505',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=506',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=507',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=508',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=509',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=510',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=511',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=512',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=513',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=514',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=515',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=516',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=517',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=518',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=519',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=520',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=521',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=522',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=523',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=524',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=525',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=526',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=527',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=528',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=529',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=530',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=531',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=532',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=533',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=534',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=535',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=536',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=537',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=538',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=539',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=540',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=541',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=542',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=543',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=544',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=545',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=546',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=547',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=548',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=549',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=550',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=551',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=552',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=553',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=554',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=555',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=556',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=557',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=558',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=559',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=560',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=561',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=562',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=563',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=564',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=565',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=566',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=567',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=568',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=569',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=570',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=571',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=572',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=573',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=574',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=575',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=576',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=577',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=578',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=579',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=580',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=581',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=582',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=583',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=584',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=585',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=586',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=587',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=588',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=589',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=590',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=591',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=592',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=593',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=594',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=595',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=596',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=597',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=598',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=599',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=600',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=601',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=602',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=603',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=604',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=605',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=606',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=607',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=608',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=609',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=610',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=611',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=612',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=613',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=614',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=615',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=616',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=617',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=618',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=619',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=620',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=621',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=622',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=623',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=624',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=625',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=626',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=627',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=628',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=629',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=630',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=631',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=632',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=633',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=634',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=635',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=636',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=637',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=638',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=639',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=640',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=641',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=642',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=643',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=644',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=645',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=646',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=647',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=648',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=649',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=650',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=651',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=652',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=653',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=654',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=655',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=656',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=657',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=658',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=659',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=660',
#  'https://www.cisa.gov/news-events/cybersecurity-advisories?page=661']

# %% [markdown]
# ## Final DataFrame: Aggregate Collection ##

# %%
df = pd.DataFrame(columns=("Publication Date", "Title", "URL","Classification"))

for page in cisa_advisory_pages[0:3]: # pages 0 to 3 for testing purposes; remove brackets for full version
    current_page = requests.get(page)
    page_html = current_page.content
    page_soup = BeautifulSoup(page_html)
    page_advisories = page_soup.find_all("article")
    for adv in page_advisories:
        entry = []
        for content in adv:
            # Extracting URLs, Titles, and publication date
            if type(content) == bs4.element.Tag:
                entry.append(content.find("time").text)
                entry.append(content.find("span").text)
                entry.append(content.find("a")['href'])
                entry.append(content.find("div").text.split("\n")[4])
                #print(entry)
                df.loc[len(df)] = entry
            else:
                pass

# %%
df.head()
# Out:
#   Publication Date  \
# 0     Jul 12, 2023
# 1     Jul 12, 2023
# 2     Jul 12, 2023
# 3     Jul 12, 2023
# 4     Jul 11, 2023
#
#                                                                                                                 Title  \
# 0                                                               CISA Releases One Industrial Control Systems Advisory
# 1  CISA and FBI Release Cybersecurity Advisory on Enhanced Monitoring to Detect APT Activity Targeting Outlook Online
# 2                                                                    Rockwell Automation Select Communication Modules
# 3                                                 Enhanced Monitoring to Detect APT Activity Targeting Outlook Online
# 4                                                                       Microsoft Releases July 2023 Security Updates
#
#                                                                                                                             URL  \
# 0                                          /news-events/alerts/2023/07/12/cisa-releases-one-industrial-control-systems-advisory
# 1  /news-events/alerts/2023/07/12/cisa-and-fbi-release-cybersecurity-advisory-enhanced-monitoring-detect-apt-activity-targeting
# 2                                                                                    /news-events/ics-advisories/icsa-23-193-01
# 3                                                                               /news-events/cybersecurity-advisories/aa23-193a
# 4                                                  /news-events/alerts/2023/07/11/microsoft-releases-july-2023-security-updates
#
#                        Classification
# 0                               Alert
# 1                               Alert
# 2       ICS Advisory | ICSA-23-193-01
# 3  Cybersecurity Advisory | AA23-193A
# 4                               Alert

# %% [markdown]
# ## Embedding html Links and completing our URL snippets. ##

# %%
def make_clickable(val):
    return f'<a target="_blank" href="https://www.cisa.gov{val}">https://www.cisa.gov{val}</a>'

# %%
# Applies formatting to make urls clickable. A happy side effect was an increased width!
df.style.format({'URL': make_clickable})
# Out:
# <style type="text/css">
# </style>
# <table id="T_40e6b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_40e6b_level0_col0" class="col_heading level0 col0" >Publication Date</th>
#       <th id="T_40e6b_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_40e6b_level0_col2" class="col_heading level0 col2" >URL</th>
#       <th id="T_40e6b_level0_col3" class="col_heading level0 col3" >Classification</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_40e6b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_40e6b_row0_col0" class="data row0 col0" >Jul 12, 2023</td>
#       <td id="T_40e6b_row0_col1" class="data row0 col1" >CISA Releases One Industrial Control Systems Advisory</td>
#       <td id="T_40e6b_row0_col2" class="data row0 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/07/12/cisa-releases-one-industrial-control-systems-advisory">https://www.cisa.gov/news-events/alerts/2023/07/12/cisa-releases-one-industrial-control-systems-advisory</a></td>
#       <td id="T_40e6b_row0_col3" class="data row0 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_40e6b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_40e6b_row1_col0" class="data row1 col0" >Jul 12, 2023</td>
#       <td id="T_40e6b_row1_col1" class="data row1 col1" >CISA and FBI Release Cybersecurity Advisory on Enhanced Monitoring to Detect APT Activity Targeting Outlook Online</td>
#       <td id="T_40e6b_row1_col2" class="data row1 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/07/12/cisa-and-fbi-release-cybersecurity-advisory-enhanced-monitoring-detect-apt-activity-targeting">https://www.cisa.gov/news-events/alerts/2023/07/12/cisa-and-fbi-release-cybersecurity-advisory-enhanced-monitoring-detect-apt-activity-targeting</a></td>
#       <td id="T_40e6b_row1_col3" class="data row1 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_40e6b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_40e6b_row2_col0" class="data row2 col0" >Jul 12, 2023</td>
#       <td id="T_40e6b_row2_col1" class="data row2 col1" >Rockwell Automation Select Communication Modules</td>
#       <td id="T_40e6b_row2_col2" class="data row2 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-193-01">https://www.cisa.gov/news-events/ics-advisories/icsa-23-193-01</a></td>
#       <td id="T_40e6b_row2_col3" class="data row2 col3" >ICS Advisory | ICSA-23-193-01</td>
#     </tr>
#     <tr>
#       <th id="T_40e6b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_40e6b_row3_col0" class="data row3 col0" >Jul 12, 2023</td>
#       <td id="T_40e6b_row3_col1" class="data row3 col1" >Enhanced Monitoring to Detect APT Activity Targeting Outlook Online</td>
#       <td id="T_40e6b_row3_col2" class="data row3 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/cybersecurity-advisories/aa23-193a">https://www.cisa.gov/news-events/cybersecurity-advisories/aa23-193a</a></td>
#       <td id="T_40e6b_row3_col3" class="data row3 col3" >Cybersecurity Advisory | AA23-193A</td>
#     </tr>
#     <tr>
#       <th id="T_40e6b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_40e6b_row4_col0" class="data row4 col0" >Jul 11, 2023</td>
#       <td id="T_40e6b_row4_col1" class="data row4 col1" >Microsoft Releases July 2023 Security Updates</td>
#       <td id="T_40e6b_row4_col2" class="data row4 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/07/11/microsoft-releases-july-2023-security-updates">https://www.cisa.gov/news-events/alerts/2023/07/11/microsoft-releases-july-2023-security-updates</a></td>
#       <td id="T_40e6b_row4_col3" class="data row4 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_40e6b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_40e6b_row5_col0" class="data row5 col0" >Jul 11, 2023</td>
#       <td id="T_40e6b_row5_col1" class="data row5 col1" >Fortinet Releases Security Update for FortiOS and FortiProxy</td>
#       <td id="T_40e6b_row5_col2" class="data row5 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/07/11/fortinet-releases-security-update-fortios-and-fortiproxy">https://www.cisa.gov/news-events/alerts/2023/07/11/fortinet-releases-security-update-fortios-and-fortiproxy</a></td>
#       <td id="T_40e6b_row5_col3" class="data row5 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_40e6b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_40e6b_row6_col0" class="data row6 col0" >Jul 11, 2023</td>
#       <td id="T_40e6b_row6_col1" class="data row6 col1" >Adobe Releases Security Updates for ColdFusion and InDesign</td>
#       <td id="T_40e6b_row6_col2" class="data row6 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/07/11/adobe-releases-security-updates-coldfusion-and-indesign">https://www.cisa.gov/news-events/alerts/2023/07/11/adobe-releases-security-updates-coldfusion-and-indesign</a></td>
#       <td id="T_40e6b_row6_col3" class="data row6 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_40e6b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_40e6b_row7_col0" class="data row7 col0" >Jul 11, 2023</td>
#       <td id="T_40e6b_row7_col1" class="data row7 col1" >Mozilla Releases Security Update for Firefox and Firefox ESR</td>
#       <td id="T_40e6b_row7_col2" class="data row7 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/07/11/mozilla-releases-security-update-firefox-and-firefox-esr">https://www.cisa.gov/news-events/alerts/2023/07/11/mozilla-releases-security-update-firefox-and-firefox-esr</a></td>
#       <td id="T_40e6b_row7_col3" class="data row7 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_40e6b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_40e6b_row8_col0" class="data row8 col0" >Jul 11, 2023</td>
#       <td id="T_40e6b_row8_col1" class="data row8 col1" >Panasonic Control FPWin Pro7</td>
#       <td id="T_40e6b_row8_col2" class="data row8 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-192-03">https://www.cisa.gov/news-events/ics-advisories/icsa-23-192-03</a></td>
#       <td id="T_40e6b_row8_col3" class="data row8 col3" >ICS Advisory | ICSA-23-192-03</td>
#     </tr>
#     <tr>
#       <th id="T_40e6b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_40e6b_row9_col0" class="data row9 col0" >Jul 11, 2023</td>
#       <td id="T_40e6b_row9_col1" class="data row9 col1" >​Sensormatic Electronics iSTAR</td>
#       <td id="T_40e6b_row9_col2" class="data row9 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-192-02">https://www.cisa.gov/news-events/ics-advisories/icsa-23-192-02</a></td>
#       <td id="T_40e6b_row9_col3" class="data row9 col3" >ICS Advisory | ICSA-23-192-02</td>
#     </tr>
#     <tr>
#       <th id="T_40e6b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_40e6b_row10_col0" class="data row10 col0" >Jul 11, 2023</td>
#       <td id="T_40e6b_row10_col1" class="data row10 col1" >Rockwell Automation Enhanced HIM</td>
#       <td id="T_40e6b_row10_col2" class="data row10 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-192-01">https://www.cisa.gov/news-events/ics-advisories/icsa-23-192-01</a></td>
#       <td id="T_40e6b_row10_col3" class="data row10 col3" >ICS Advisory | ICSA-23-192-01</td>
#     </tr>
#     <tr>
#       <th id="T_40e6b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_40e6b_row11_col0" class="data row11 col0" >Jul 11, 2023</td>
#       <td id="T_40e6b_row11_col1" class="data row11 col1" >CISA Adds Five Known Vulnerabilities to Catalog</td>
#       <td id="T_40e6b_row11_col2" class="data row11 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/07/11/cisa-adds-five-known-vulnerabilities-catalog">https://www.cisa.gov/news-events/aler

# %% [markdown]
# ## Creating a Rolling Window Feed (Batch Mode) ##

# %%
# Update feed routinely
from IPython.display import display, clear_output

# %%
# Display and refresh feed on a routine basis 
# with i serving as a marker / placeholder for the next iteration of entries in the sequence. 

refresh_rate = 5 # needs to refresh every 5 seconds with the next 10 entries
window_size = 10
i = 0

#df.style.format({'URL': make_clickable})

while(i < len(df)):
    view = df[df.index > i]
    clear_output(wait=True)
    display(view.head(window_size).style.format({'URL': make_clickable}))
    time.sleep(refresh_rate)
    # num rows to move our window after the refresh. In this example iteration rate is consistent with window_size
    i = i + window_size
# Out:
# <style type="text/css">
# </style>
# <table id="T_126da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_126da_level0_col0" class="col_heading level0 col0" >Publication Date</th>
#       <th id="T_126da_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_126da_level0_col2" class="col_heading level0 col2" >URL</th>
#       <th id="T_126da_level0_col3" class="col_heading level0 col3" >Classification</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_126da_level0_row0" class="row_heading level0 row0" >21</th>
#       <td id="T_126da_row0_col0" class="data row0 col0" >Jul 06, 2023</td>
#       <td id="T_126da_row0_col1" class="data row0 col1" >MAR-10445155-1.v1 Truebot Activity Infects U.S. and Canada Based Networks</td>
#       <td id="T_126da_row0_col2" class="data row0 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/analysis-reports/ar23-187a">https://www.cisa.gov/news-events/analysis-reports/ar23-187a</a></td>
#       <td id="T_126da_row0_col3" class="data row0 col3" >Analysis Report | AR23-187A</td>
#     </tr>
#     <tr>
#       <th id="T_126da_level0_row1" class="row_heading level0 row1" >22</th>
#       <td id="T_126da_row1_col0" class="data row1 col0" >Jun 30, 2023</td>
#       <td id="T_126da_row1_col1" class="data row1 col1" >DoS and DDoS Attacks against Multiple Sectors</td>
#       <td id="T_126da_row1_col2" class="data row1 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/06/30/dos-and-ddos-attacks-against-multiple-sectors">https://www.cisa.gov/news-events/alerts/2023/06/30/dos-and-ddos-attacks-against-multiple-sectors</a></td>
#       <td id="T_126da_row1_col3" class="data row1 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_126da_level0_row2" class="row_heading level0 row2" >23</th>
#       <td id="T_126da_row2_col0" class="data row2 col0" >Jun 29, 2023</td>
#       <td id="T_126da_row2_col1" class="data row2 col1" >CISA Releases Nine Industrial Control Systems Advisories</td>
#       <td id="T_126da_row2_col2" class="data row2 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/06/29/cisa-releases-nine-industrial-control-systems-advisories">https://www.cisa.gov/news-events/alerts/2023/06/29/cisa-releases-nine-industrial-control-systems-advisories</a></td>
#       <td id="T_126da_row2_col3" class="data row2 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_126da_level0_row3" class="row_heading level0 row3" >24</th>
#       <td id="T_126da_row3_col0" class="data row3 col0" >Jun 29, 2023</td>
#       <td id="T_126da_row3_col1" class="data row3 col1" >2023 CWE Top 25 Most Dangerous Software Weaknesses</td>
#       <td id="T_126da_row3_col2" class="data row3 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/06/29/2023-cwe-top-25-most-dangerous-software-weaknesses">https://www.cisa.gov/news-events/alerts/2023/06/29/2023-cwe-top-25-most-dangerous-software-weaknesses</a></td>
#       <td id="T_126da_row3_col3" class="data row3 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_126da_level0_row4" class="row_heading level0 row4" >25</th>
#       <td id="T_126da_row4_col0" class="data row4 col0" >Jun 29, 2023</td>
#       <td id="T_126da_row4_col1" class="data row4 col1" >Medtronic Paceart Optima System </td>
#       <td id="T_126da_row4_col2" class="data row4 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-medical-advisories/icsma-23-180-01">https://www.cisa.gov/news-events/ics-medical-advisories/icsma-23-180-01</a></td>
#       <td id="T_126da_row4_col3" class="data row4 col3" >ICS Medical Advisory | ICSMA-23-180-01</td>
#     </tr>
#     <tr>
#       <th id="T_126da_level0_row5" class="row_heading level0 row5" >26</th>
#       <td id="T_126da_row5_col0" class="data row5 col0" >Jun 29, 2023</td>
#       <td id="T_126da_row5_col1" class="data row5 col1" >​Mitsubishi Electric MELSEC-F Series (Update A)</td>
#       <td id="T_126da_row5_col2" class="data row5 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-04">https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-04</a></td>
#       <td id="T_126da_row5_col3" class="data row5 col3" >ICS Advisory | ​​ICSA-23-180-04</td>
#     </tr>
#     <tr>
#       <th id="T_126da_level0_row6" class="row_heading level0 row6" >27</th>
#       <td id="T_126da_row6_col0" class="data row6 col0" >Jun 29, 2023</td>
#       <td id="T_126da_row6_col1" class="data row6 col1" >​Ovarro TBox RTUs</td>
#       <td id="T_126da_row6_col2" class="data row6 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-03">https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-03</a></td>
#       <td id="T_126da_row6_col3" class="data row6 col3" >ICS Advisory | ICSA-23-180-03</td>
#     </tr>
#     <tr>
#       <th id="T_126da_level0_row7" class="row_heading level0 row7" >28</th>
#       <td id="T_126da_row7_col0" class="data row7 col0" >Jun 29, 2023</td>
#       <td id="T_126da_row7_col1" class="data row7 col1" >Schneider Electric EcoStruxure Operator Terminal Expert</td>
#       <td id="T_126da_row7_col2" class="data row7 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-02">https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-02</a></td>
#       <td id="T_126da_row7_col3" class="data row7 col3" >ICS Advisory | ICSA-23-180-02</td>
#     </tr>
#     <tr>
#       <th id="T_126da_level0_row8" class="row_heading level0 row8" >29</th>
#       <td id="T_126da_row8_col0" class="data row8 col0" >Jun 29, 2023</td>
#       <td id="T_126da_row8_col1" class="data row8 col1" >Delta Electronics InfraSuite Device Master</td>
#       <td id="T_126da_row8_col2" class="data row8 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-01">https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-01</a></td>
#       <td id="T_126da_row8_col3" class="data row8 col3" >ICS Advisory | ICSA-23-180-01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Creating a Flowing Window Feed (Streaming Mode) ##

# %%
df.head(1).index
# Out:
# Index([0], dtype='int64')

# %%
# However our feed can be made to flow more naturally with the next entry displayed at the top, streaming sequentially
# This requires slower iteration and a faster refresh rate

refresh_rate = 1
window_size = 10
iteration_rate = 1
marker = 0

while(marker < len(df)-window_size):
    view = df[df.index > marker]
    clear_output(wait=True)
    display(view.head(window_size).style.set_properties(**{'text-align': 'left'}, **{'background-color': '#b3cc83'}, **{'border-bottom': 'solid'}).format({'URL': make_clickable}))
    time.sleep(refresh_rate)
    # num rows to move our window after the refresh. 
    marker = marker + iteration_rate
    #df.style.set_properties(subset=["Title", "URL"], **{'text-align': 'left'}).format({'URL': make_clickable})
# Out:
# <style type="text/css">
# #T_aec87_row0_col0, #T_aec87_row0_col1, #T_aec87_row0_col2, #T_aec87_row0_col3, #T_aec87_row1_col0, #T_aec87_row1_col1, #T_aec87_row1_col2, #T_aec87_row1_col3, #T_aec87_row2_col0, #T_aec87_row2_col1, #T_aec87_row2_col2, #T_aec87_row2_col3, #T_aec87_row3_col0, #T_aec87_row3_col1, #T_aec87_row3_col2, #T_aec87_row3_col3, #T_aec87_row4_col0, #T_aec87_row4_col1, #T_aec87_row4_col2, #T_aec87_row4_col3, #T_aec87_row5_col0, #T_aec87_row5_col1, #T_aec87_row5_col2, #T_aec87_row5_col3, #T_aec87_row6_col0, #T_aec87_row6_col1, #T_aec87_row6_col2, #T_aec87_row6_col3, #T_aec87_row7_col0, #T_aec87_row7_col1, #T_aec87_row7_col2, #T_aec87_row7_col3, #T_aec87_row8_col0, #T_aec87_row8_col1, #T_aec87_row8_col2, #T_aec87_row8_col3, #T_aec87_row9_col0, #T_aec87_row9_col1, #T_aec87_row9_col2, #T_aec87_row9_col3 {
#   text-align: left;
#   background-color: #b3cc83;
#   border-bottom: solid;
# }
# </style>
# <table id="T_aec87">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aec87_level0_col0" class="col_heading level0 col0" >Publication Date</th>
#       <th id="T_aec87_level0_col1" class="col_heading level0 col1" >Title</th>
#       <th id="T_aec87_level0_col2" class="col_heading level0 col2" >URL</th>
#       <th id="T_aec87_level0_col3" class="col_heading level0 col3" >Classification</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aec87_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_aec87_row0_col0" class="data row0 col0" >Jul 06, 2023</td>
#       <td id="T_aec87_row0_col1" class="data row0 col1" >CISA and Partners Release Joint Cybersecurity Advisory on Newly Identified Truebot Malware Variants </td>
#       <td id="T_aec87_row0_col2" class="data row0 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/07/06/cisa-and-partners-release-joint-cybersecurity-advisory-newly-identified-truebot-malware-variants">https://www.cisa.gov/news-events/alerts/2023/07/06/cisa-and-partners-release-joint-cybersecurity-advisory-newly-identified-truebot-malware-variants</a></td>
#       <td id="T_aec87_row0_col3" class="data row0 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_aec87_level0_row1" class="row_heading level0 row1" >21</th>
#       <td id="T_aec87_row1_col0" class="data row1 col0" >Jul 06, 2023</td>
#       <td id="T_aec87_row1_col1" class="data row1 col1" >MAR-10445155-1.v1 Truebot Activity Infects U.S. and Canada Based Networks</td>
#       <td id="T_aec87_row1_col2" class="data row1 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/analysis-reports/ar23-187a">https://www.cisa.gov/news-events/analysis-reports/ar23-187a</a></td>
#       <td id="T_aec87_row1_col3" class="data row1 col3" >Analysis Report | AR23-187A</td>
#     </tr>
#     <tr>
#       <th id="T_aec87_level0_row2" class="row_heading level0 row2" >22</th>
#       <td id="T_aec87_row2_col0" class="data row2 col0" >Jun 30, 2023</td>
#       <td id="T_aec87_row2_col1" class="data row2 col1" >DoS and DDoS Attacks against Multiple Sectors</td>
#       <td id="T_aec87_row2_col2" class="data row2 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/06/30/dos-and-ddos-attacks-against-multiple-sectors">https://www.cisa.gov/news-events/alerts/2023/06/30/dos-and-ddos-attacks-against-multiple-sectors</a></td>
#       <td id="T_aec87_row2_col3" class="data row2 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_aec87_level0_row3" class="row_heading level0 row3" >23</th>
#       <td id="T_aec87_row3_col0" class="data row3 col0" >Jun 29, 2023</td>
#       <td id="T_aec87_row3_col1" class="data row3 col1" >CISA Releases Nine Industrial Control Systems Advisories</td>
#       <td id="T_aec87_row3_col2" class="data row3 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/06/29/cisa-releases-nine-industrial-control-systems-advisories">https://www.cisa.gov/news-events/alerts/2023/06/29/cisa-releases-nine-industrial-control-systems-advisories</a></td>
#       <td id="T_aec87_row3_col3" class="data row3 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_aec87_level0_row4" class="row_heading level0 row4" >24</th>
#       <td id="T_aec87_row4_col0" class="data row4 col0" >Jun 29, 2023</td>
#       <td id="T_aec87_row4_col1" class="data row4 col1" >2023 CWE Top 25 Most Dangerous Software Weaknesses</td>
#       <td id="T_aec87_row4_col2" class="data row4 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/alerts/2023/06/29/2023-cwe-top-25-most-dangerous-software-weaknesses">https://www.cisa.gov/news-events/alerts/2023/06/29/2023-cwe-top-25-most-dangerous-software-weaknesses</a></td>
#       <td id="T_aec87_row4_col3" class="data row4 col3" >Alert</td>
#     </tr>
#     <tr>
#       <th id="T_aec87_level0_row5" class="row_heading level0 row5" >25</th>
#       <td id="T_aec87_row5_col0" class="data row5 col0" >Jun 29, 2023</td>
#       <td id="T_aec87_row5_col1" class="data row5 col1" >Medtronic Paceart Optima System </td>
#       <td id="T_aec87_row5_col2" class="data row5 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-medical-advisories/icsma-23-180-01">https://www.cisa.gov/news-events/ics-medical-advisories/icsma-23-180-01</a></td>
#       <td id="T_aec87_row5_col3" class="data row5 col3" >ICS Medical Advisory | ICSMA-23-180-01</td>
#     </tr>
#     <tr>
#       <th id="T_aec87_level0_row6" class="row_heading level0 row6" >26</th>
#       <td id="T_aec87_row6_col0" class="data row6 col0" >Jun 29, 2023</td>
#       <td id="T_aec87_row6_col1" class="data row6 col1" >​Mitsubishi Electric MELSEC-F Series (Update A)</td>
#       <td id="T_aec87_row6_col2" class="data row6 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-04">https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-04</a></td>
#       <td id="T_aec87_row6_col3" class="data row6 col3" >ICS Advisory | ​​ICSA-23-180-04</td>
#     </tr>
#     <tr>
#       <th id="T_aec87_level0_row7" class="row_heading level0 row7" >27</th>
#       <td id="T_aec87_row7_col0" class="data row7 col0" >Jun 29, 2023</td>
#       <td id="T_aec87_row7_col1" class="data row7 col1" >​Ovarro TBox RTUs</td>
#       <td id="T_aec87_row7_col2" class="data row7 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-03">https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-03</a></td>
#       <td id="T_aec87_row7_col3" class="data row7 col3" >ICS Advisory | ICSA-23-180-03</td>
#     </tr>
#     <tr>
#       <th id="T_aec87_level0_row8" class="row_heading level0 row8" >28</th>
#       <td id="T_aec87_row8_col0" class="data row8 col0" >Jun 29, 2023</td>
#       <td id="T_aec87_row8_col1" class="data row8 col1" >Schneider Electric EcoStruxure Operator Terminal Expert</td>
#       <td id="T_aec87_row8_col2" class="data row8 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-02">https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-02</a></td>
#       <td id="T_aec87_row8_col3" class="data row8 col3" >ICS Advisory | ICSA-23-180-02</td>
#     </tr>
#     <tr>
#       <th id="T_aec87_level0_row9" class="row_heading level0 row9" >29</th>
#       <td id="T_aec87_row9_col0" class="data row9 col0" >Jun 29, 2023</td>
#       <td id="T_aec87_row9_col1" class="data row9 col1" >Delta Electronics InfraSuite Device Master</td>
#       <td id="T_aec87_row9_col2" class="data row9 col2" ><a target="_blank" href="https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-01">https://www.cisa.gov/news-events/ics-advisories/icsa-23-180-01</a></td>
#       <td id="T_aec87_row9_col3" class="data row9 col3" >ICS Advisory | ICSA-23-180-01</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Sources: ###
#
# A Text-Mining Approach to Cyberrisk Management - https://www.isaca.org/-/media/files/isacadp/project/isaca/articles/journal/2021/volume-6/a-text-mining-approach-to-cyberrisk-management-joa-eng-1121.pdf
#
# HTML Formatting in Pandas DataFrame - https://stackoverflow.com/questions/40724475/html-formatting-in-pandas-dataframe
#
# How to create clickable Links - https://datascientyst.com/create-clickable-link-pandas-dataframe-jupyterlab/
#
# Refresh a Panda dataframe while printing using loop - https://stackoverflow.com/questions/65024047/refresh-a-panda-dataframe-while-printing-using-loop
#
# Get item from bs4.element.Tag - https://stackoverflow.com/questions/57395509/get-item-from-bs4-element-tag
#
# How to get the next page on BeautifulSoup? - https://www.geeksforgeeks.org/how-to-get-the-next-page-on-beautifulsoup/#
#
# CISA’s Shields Up: What it is, how to use it - https://www.scmagazine.com/sw-article/asset-management/cisas-shields-up-what-it-is-how-to-use-it
#
# How to left align a dataframe column in python? - http://stackoverflow.com/questions/53460941/ddg#56042544

# %%
# For future improvement: 

## 1) Consider marking entries by a color scheme indicating varying levels of danger
## 2) Run a cron job on a weekly basis in order to get a feed of the latest articles and advisories
